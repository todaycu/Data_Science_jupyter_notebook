# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# # Tolera Degefa

# %%
Student at Alx

# %% [markdown]
# _I'm intersted in data science to be able to predict the quality of water going into the system_

# %% [markdown]
# The code below is a while loop to see how many iteration it take i to reach a value above 100 and what the value of i would be.

# %%
i=1
k=0
while (i<100):
    i*=2
    k+=1
print(i)
print(k)
# Out:
# 128
# 7

# %%
Bulleted lists

# %%
.one

# %%
.two

# %%
.three

# %%
Inline-style:

# %%
s = "Python syntax highlighting"
print s

# %% [markdown]
# ![RE4wHgp.jpeg](attachment:RE4wHgp.jpeg)
